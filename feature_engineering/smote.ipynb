# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=2000,n_features=2,n_redundant=0,n_clusters_per_class=1,weights=[0.90],random_state=42)

# %%
import pandas as pd
df1=pd.DataFrame(x,columns=['f1',"f2"])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -1.274727  1.114904       0
# 1 -1.237095  1.478085       0
# 2 -0.676592  1.400954       0
# 3 -0.243106  0.571861       0
# 4 -1.723880  1.256747       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    1796
# 1     204
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])
plt.title("Before SMOTE")
plt.show()

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
x,y=oversample.fit_resample(final_df[['f1', 'f2']], final_df['target'])
x.shape
# Out:
# (3592, 2)

# %%
y.shape
# Out:
# (3592,)

# %%
df1=pd.DataFrame(x,columns=['f1',"f2"])
df2=pd.DataFrame(y,columns=['target'])
oversample_df=pd.concat([df1,df2],axis=1)

# %%
# Plot after SMOTE
plt.scatter(oversample_df['f1'], oversample_df['f2'], c=oversample_df['target'])
plt.title("After SMOTE")
plt.show()
