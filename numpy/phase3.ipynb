# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("==== Zomato sales analysis ==== ")
print("\n Sales data shape: ",sales_data.shape)
print("\n Sample data for first 3 resturants: \n",sales_data[0:3]) #getting first thre columns

# %% [markdown]
# # Total sales per year

# %%
yearly=np.sum(sales_data[:,1:],axis=0)
print(yearly)

#minimum sales
minium=np.min(sales_data[:,1:],axis=1)
print(minium)

#maximun sales per year
maximum_sales=np.max(sales_data[:,1:],axis=0)
print(maximum_sales)

#average sales per restureant 
average_sales=np.average(sales_data[:,1:],axis=1)
print(average_sales)

#cumulative sales
cumsum=np.cumsum(sales_data[:,1:],axis=1)
print(cumsum)

# %%
plt.figure(figsize=(6,4))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average cumulative sales across all resturant: ")
plt.xlabel("Years")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
#calculate the monthly average

monthly_sales=sales_data[:,1:] / 12 
print("The average monthly sales: \n",monthly_sales)
# Out:
# The average monthly sales:
#  [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'age': [23, 45, 31, 35, 25, 40, 29, 30, 41, 37]}
df = pd.DataFrame(data)
# Create a histogram
df['age'].hist(bins=5, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#detecting outliers using boxplot
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame
df = pd.DataFrame({
    'scores': [45, 48, 52, 53, 55, 58, 59, 61, 65, 70, 100]
})

# Boxplot
df.boxplot(column='scores')
plt.title('Boxplot of Scores')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 100)
pdf = norm.pdf(x, loc=0, scale=1)  # mean = 0, std = 1

plt.plot(x, pdf)
plt.title("Standard Normal Distribution PDF")
plt.xlabel("x")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, expon, uniform

x = np.linspace(-4, 10, 500)
plt.figure(figsize=(10, 6))

# Normal
plt.plot(x, norm.pdf(x, loc=2, scale=1), label='Normal (μ=2, σ=1)', linewidth=2)

# Exponential
plt.plot(x, expon.pdf(x, scale=2), label='Exponential (λ=0.5)', linewidth=2)

# Uniform
plt.plot(x, uniform.pdf(x, loc=0, scale=8), label='Uniform [0, 8]', linewidth=2)

plt.title("Comparison of Common Continuous Distributions")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
