# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#basic plotting with seaborn
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
##create a scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter plot of Total Bill vs Tip")
plt.show()

# %%
## line plot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line plot of Size vs Total Bill")
plt.show()

# %%
## Categorical plot (bar plot)
sns.barplot(x='day',y='total_bill',data=tips )
plt.title("Bar plot of Total Bill by Day")
plt.show()

# %%
## box plot
sns.boxplot(x='day',y='total_bill', data=tips)
plt.title("Box plot of Day by Total Bill")
plt.show()

# %%
## Voilin plot 
sns.violinplot(x='day',y='total_bill', data=tips)
plt.title("Violin plot of Day by Total Bill")
plt.show()

# %%
## Histogram
sns.histplot(tips['total_bill'], bins=20, kde=True)
plt.title("Histogram of Total Bill")
plt.show()

# %%
## KDE plot
sns.kdeplot(tips['total_bill'], shade=True)
plt.title("KDE plot of Total Bill")
plt.show()
# Out:
# /var/folders/ry/tmfwxy_56zz3pz3mngltbfkw0000gn/T/ipykernel_33796/4113731325.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True)

# %%
#Pair plot
sns.pairplot(tips, hue='day')

# %%
#Heatmap
corr=tips[['total_bill','tip','size']].corr() 
corr
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Heatmap of Total Bill, Tip, and Size")
plt.show()

# %%
## customization
import pandas as pd 
df=pd.read_csv('customer_data.csv')
df
# Out:
#                                CustomerID                 Name  \
# 0    e7e55a25-589d-44f7-b86a-c5f85ebcfe3e     Edward Stevenson
# 1    1366b9fb-51d9-4e9c-b3a6-36022e1d0c9d       Scott Campbell
# 2    341abcf8-94ff-4127-9e40-a6de8dc84a40  Mr. George Stafford
# 3    c76ab336-2b6f-4087-9d1b-14a541286564      Mr. David Smith
# 4    3c779088-6e9a-42e8-a45c-33053ad192e2      Taylor Ferguson
# ..                                    ...                  ...
# 495  c612607b-8b69-4905-9e16-18dc97c2ca05           Todd Roach
# 496  cfc293f5-9fa1-43a4-86f1-4ba1b030baa1       Joann Thompson
# 497  882bad77-a69b-4e25-8132-e092f26a8e63        Donald Savage
# 498  dd9a0562-f6df-4dee-8b23-da58e1ba5f06          Erin Bender
# 499  1072718c-7818-4dc1-9175-f6ff3470e1ab         Angela Clark
#
#                             Email  SignupDate            Country  Age  \
# 0    ericaowen@miller-ferrell.com  2025-03-31            Comoros   18
# ...

# %%
# Calculate average spending score by country
avg_spending = df.groupby('Country', as_index=False)['SpendingScore'].mean().sort_values(by='SpendingScore', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='SpendingScore', data=avg_spending, palette='viridis')
plt.title('Top 10 Countries by Average Spending Score')

plt.show()
# Out:
# /var/folders/ry/tmfwxy_56zz3pz3mngltbfkw0000gn/T/ipykernel_33796/1033481498.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='SpendingScore', data=avg_spending, palette='viridis')
